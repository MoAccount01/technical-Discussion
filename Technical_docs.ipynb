# %% [markdown]
# <a href="https://colab.research.google.com/github/MoAccount01/technical-Discussion/blob/main/Technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
   return "Hi"
hello()
# Out:
# 'Hi'

# %% [markdown]
# ## EDA

# %% [markdown]
# ## **Modeling**
